# %%
import sys
from pathlib import Path

# Add project root to path
project_root = Path('.').resolve()
sys.path.append(str(project_root))

print("✅ Setup complete!")
# Out:
# ✅ Setup complete!

# %%
from universal_trainer import ModelRegistry

registry = ModelRegistry(models_dir='modelFolder')
registry.list_models()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from universal_trainer import ModelRegistry
#       3 registry = ModelRegistry(models_dir='modelFolder')
#       4 registry.list_models()
#
# ImportError: cannot import name 'ModelRegistry' from 'universal_trainer' (d:\research\codes\universal_trainer.py)
